# %%
# Import necessary libraries if needed
# import numpy as np
# import pandas as pd

# Define a function to calculate the sum of N natural numbers
def sum_of_natural_numbers(N):
    total = 0
    for i in range(1, N + 1):
        total += i
    return total

# Input the value of N
N = 10  # You can change this to any positive integer

# Calculate the sum and print the result
result = sum_of_natural_numbers(N)
print(f"The sum of the first {N} natural numbers is: {result}")
# Out:
# The sum of the first 10 natural numbers is: 55

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# Load the MNIST dataset
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data
train_images = train_images / 255.0
test_images = test_images / 255.0

# Create a simple neural network model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=5, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_accuracy}")

# Plot training history
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

plt.show()
# Out:
# ...
# 11490434/11490434 [==============================] - 19s 2us/step
# Epoch 1/5
# 1500/1500 [==============================] - 1s 545us/step - loss: 0.3278 - accuracy: 0.9049 - val_loss: 0.1535 - val_accuracy: 0.9557
# Epoch 2/5
# 1500/1500 [==============================] - 1s 501us/step - loss: 0.1572 - accuracy: 0.9531 - val_loss: 0.1216 - val_accuracy: 0.9643
# Epoch 3/5
# 1500/1500 [==============================] - 1s 500us/step - loss: 0.1172 - accuracy: 0.9647 - val_loss: 0.0977 - val_accuracy: 0.9714
# Epoch 4/5
# 1500/1500 [==============================] - 1s 500us/step - loss: 0.0945 - accuracy: 0.9711 - val_loss: 0.0934 - val_accuracy: 0.9742
# Epoch 5/5
# ...
# 313/313 [==============================] - 0s 289us/step - loss: 0.0829 - accuracy: 0.9737
# Test accuracy: 0.9736999869346619

# %%
print ("Welcome to Guru99")
# Out:
# Welcome to Guru99

# %%
print ("Welcome to", end = ' ') 
print ("Guru99", end = '!')
# Out:
# Welcome to Guru99!

# %%
print ("Sushanta")
print("\n\n")
print("Saha")
# Out:
# Sushanta
#
#
#
# Saha

# %%
print ("Sushanta", end = ' ') 
print ("Saha", end = '!')
# Out:
# Sushanta Saha!

# %%
print ("Sushanta", end =' ')
print("Saha")
# Out:
# Sushanta Saha

# %%
print("Sushanta")
print ("Saha")
# Out:
# Sushanta
# Saha

# %%
//Print syntax
print("Sushanta")
print ("Saha")
# Out:
#   Cell In[11], line 1
#     //Print syntax
#     ^
# SyntaxError: invalid syntax

# %%
#Print syntax
print ("Sushanta Saha")
# Out:
# Sushanta Saha

# %%
#Print Syntax with Print end command
Print ("Sushanta", end='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 #Print Syntax with Print end command
# ----> 2 Print ("Sushanta", end='')
#
# NameError: name 'Print' is not defined

# %%
#Print Syntax with Print end command
print ("Sushanta", end='')
# Out:
# Sushanta

# %%
# ends the output with ‘@.’
print("sushanta",end='@',"royalmagpie.com")
# Out:
#   Cell In[15], line 2
#     print("sushanta",end='@',"royalmagpie.com")
#                                               ^
# SyntaxError: positional argument follows keyword argument

# %%
## ends the output with ‘@.’

print ("sushanta", end='@')
print ("royalmagpie.com")
print("\n")
print ("monirul", end='@')
print ("royalmagpie.com")
# Out:
# sushanta@royalmagpie.com
#
#
# monirul@royalmagpie.com

# %%
## ends the output with ‘@.’

print ("sushanta", end='@')
print ("royalmagpie.com")
print ("monirul", end='@')
print ("royalmagpie.com")
# Out:
# sushanta@royalmagpie.com
# monirul@royalmagpie.com

# %%
#How to Declare and use a Variable

a = 100
print (a)
# Out:
# 100

# %%
a = "Sushanta"
print (a)
# Out:
# Sushanta

# %%
a = 100
b = 100
c = a + b
print (c)
# Out:
# 200

# %%
a = "Sushanta"
b = "Saha"
c = a+b
print (c)
# Out:
# SushantaSaha

# %%
## Python String Concatenation and Variable
a = "Sushanta "
b = 100
print (a + str(b))
# Out:
# Sushanta 100

# %%
## Python String Concatenation and Variable
a = "Sushanta "
b = 100
print ("The value of this program is", a + str(b))
# Out:
# The value of this program is Sushanta 100

# %%
a =  "I am learing Python with Jupyter using Anaconda"
print(a)
# Out:
# I am learing Python with Jupyter using Anaconda

# %%
# Python Variable Types: Local & Global
# Declare a variable and initialize it

f = 100
print (f)

# Global vs. local variables in functions
def someFunction():
    f = "I am Learning Python"
    print (f)
    
    someFunction() ## there is problem <
    print (f)
# Out:
# 100

# %%
# Declare a variable and initialize it
f = 101
print (f)
# Global vs. local variables in functions
def someFunction():
# global f
    f = 'I am learning Python'
    print (f)
someFunction()
#print (f)
# Out:
# 101
# I am learning Python

# %%
# Declare local variable when you want to use it for current function
# Declare Global variable when you want to use the same variable for rest of the program

f = 100
print (f)

def someFunction():
    global f
print (f)

f = 'Learning Global variable and local variable'
#someFunction()
print (f)

f= 200
print (f)

f = "Sushanta"
print (f)

g = 100
print (g)

g ="Saha"

print (g)
# Out:
# 100
# 100
# Learning Global variable and local variable
# 200
# Sushanta
# 100
# Saha

# %%
# Delete a variable in python (Command)
# To delete a variable, it uses keyword “del”.

f = 1000
print (f)

del f

print (f)
# Out:
# 1000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 8
#       4 print (f)
#       6 del f
# ----> 8 print (f)
#
# NameError: name 'f' is not defined

# %%
##Python Escape Character Sequences (Examples)
##============================================
##the escape character could be t, n, e, or backslash itself.

## \n	New Line - The new line character helps the programmer to insert a new line before or after a string.

txt = 'Sushanta\nSaha'
print (txt)

## \\	 Backslash - This escape sequence allows the programmer to insert a backslash into the Python output.

txt = "\nSushanta\\Saha"
print (txt)

## \xhh	 Hexadecimal equivalent - Use a backslash followed by a hexadecimal number.
## This is done by printing in backslash with the hexadecimal equivalent in double quotes.

txt = "\n\x53\x75\x73\x68\x61\x6E\x74\x61 \x53\x61\x68\x61"
print (txt)
# Out:
# Sushanta
# Saha
#
# Sushanta\Saha
#
# Sushanta Saha

# %%
print (t)
# Out:
# SushantaSaha

# %%
# \b	This escape sequence provides backspace to the Python string. It is inserted by adding a backslash followed by “b”.
# “b” here represents backslash.

txt = "Sushanta\b Saha99"
print(txt)
# Out:
# Saha99

# %%
# \f	It helps in the interpolation of literal strings

txt = "Sushanta\f Saha"
print(txt)
# Out:
# Sushanta Saha

# %%
# \r	It helps you to create a raw string   (error coming in Code)

txt = "Sushanta\r Saha"
print(txt)
# Out:
#  Saha

# %%
# \’	It helps you to add a single quotation to string

txt = "Sushanta\'Saha"
print (txt)
# Out:
# Sushanta'Saha

# %%
# “\t” In this example, the string used is “Guru99”. The program will put a tab or a space between Guru and 99.

txt ="Sushanta\tSaha"

print (txt)
# Out:
# Sushanta	Saha

# %%
## How to Check Python Version on Linux, Mac & Windows

python –version    Command line or Terminal
python -v          Command line or Terminal
python -vv         Command line or Terminal

Import sys
sys. version

How to check the Python version using a script?

In Command line

import sys
sys. version
## https://www.guru99.com/check-python-version.html
# Out:
#   Cell In[1], line 3
#     python –version    Command line or Terminal
#            ^
# SyntaxError: invalid character '–' (U+2013)
